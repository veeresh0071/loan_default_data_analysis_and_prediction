# %%
import pandas as pd 
import numpy as np 

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier

from sklearn.metrics import accuracy_score , r2_score
import pickle

# %%
rdf = pd.read_csv('Loan_default.csv')

# %%
df.head()
# Out:
#    Income  LoanAmount  CreditScore  InterestRate    Education EmploymentType  \
# 0   85994       50587          520         15.23   Bachelor's      Full-time
# 1   50432      124440          458          4.81     Master's      Full-time
# 2   84208      129188          451         21.17     Master's     Unemployed
# 3   31713       44799          743          7.07  High School      Full-time
# 4   20437        9139          633          6.51   Bachelor's     Unemployed
#
#   HasMortgage HasDependents LoanPurpose  Default
# 0         Yes           Yes       Other        0
# 1          No            No       Other        0
# 2         Yes           Yes        Auto        1
# 3          No            No    Business        0
# 4          No           Yes        Auto        0

# %%
df.dtypes
# Out:
# Income              int64
# LoanAmount          int64
# CreditScore         int64
# InterestRate      float64
# Education          object
# EmploymentType     object
# HasMortgage        object
# HasDependents      object
# LoanPurpose        object
# Default             int64
# dtype: object

# %%
x_train , x_test , y_train , y_test = train_test_split(
    df.drop('Default',axis=1),
    df['Default'],
    test_size=0.1,
    random_state=10
)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (229812, 9)
# (25535, 9)
# (229812,)
# (25535,)

# %%
algorithms = [RandomForestClassifier, KNeighborsClassifier , LogisticRegression , DecisionTreeClassifier]
models_accuracy = []
modelsR2_score = []

# %%
for algo in algorithms:
    
    #Pipeline Buiding
    preprocessor = ColumnTransformer([
    ('onehot', OneHotEncoder(), [4,5,6,7,8]),
    ('scaler', StandardScaler(), [0,1,2,3])
    ])

    pipeline = Pipeline([
    ('preprocessor', preprocessor),
    ('classifier', RandomForestClassifier())
    ])

    pipeline.fit(x_train,y_train)
    y_pred = pipeline.predict(x_test)
    accuracy = accuracy_score(y_test,y_pred)
    r2 = r2_score(y_test,y_pred)
    models_accuracy.append(accuracy)
    modelsR2_score.append(r2)

# %%
models_accuracy
# Out:
# [0.8807519091443118,
#  0.8816526336401018,
#  0.8814176620325044,
#  0.8815743097709027]

# %%
preprocessor = ColumnTransformer([
    ('onehot', OneHotEncoder(), [4,5,6,7,8]),
    ('scaler', StandardScaler(), [0,1,2,3])
])

pipeline = Pipeline([
    ('preprocessor', preprocessor),
    ('classifier', KNeighborsClassifier())
])

# %%
pipeline.fit(x_train,y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('onehot', OneHotEncoder(),
#                                                   [4, 5, 6, 7, 8]),
#                                                  ('scaler', StandardScaler(),
#                                                   [0, 1, 2, 3])])),
#                 ('classifier', KNeighborsClassifier())])

# %%
y_pred = pipeline.predict(x_test)
accuracy = accuracy_score(y_test,y_pred)
print(accuracy)
# Out:
# 0.8690816526336401

# %%
pickle.dump(pipeline, open('Loan Default.sav', 'wb'))

# %%
del pipeline

# %%
load_model = pickle.load(open('Loan Default.sav', 'rb'))

# %%
load_model.predict(x_test[:1])
# Out:
# array([0], dtype=int64)
